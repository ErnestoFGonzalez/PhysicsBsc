# %%
import pylab


class DerivativeApproxManager():
    def __init__(self, function, function_derivative, x_point, h_values):
        self.function = function
        self.function_derivative = function_derivative
        self.x = x_point
        self.h_values = h_values

    def approx_function_derivative(self, h):
        return (self.function(self.x+h)-self.function(self.x))/h

    def approx_abs_error(self, h):
        return abs(self.function_derivative(self.x)-self.approx_function_derivative(h))

    def absolute_error_per_h(self, plot_title, x_label, y_label, plot_filename):
        absolute_error_per_h = []
        for h in self.h_values:
            print("h={} \t absolute_error={}".format(h, self.approx_abs_error(h)))
            absolute_error_per_h.append(self.approx_abs_error(h))

        # Plot absolute_error_per_h per h in log scale axis
        pylab.figure(figsize=(10,10))
        pylab.loglog(self.h_values, absolute_error_per_h, 'ro')
        pylab.grid(color='k', linestyle='--', linewidth=0.5)
        # pylab.title(plot_title, fontsize=20, fontweight='bold')
        pylab.xticks(fontsize=22)
        pylab.yticks(fontsize=22)
        pylab.xlabel(x_label, fontsize=23)
        pylab.ylabel(y_label, fontsize=23)
        pylab.savefig(plot_filename)
        pylab.show()

# %%
def f(x):
    return x**2
def f_linha(x):
    return 2*x

# %%
valores_h10 = [10**(-i) for i in range(21)]
erros_base10 = DerivativeApproxManager(x_point=1,
                                       function=f,
                                       function_derivative=f_linha,
                                       h_values=valores_h10)

# %%
erros_base10.absolute_error_per_h(
    plot_title="Erros Absolutos de Aproximações à primeira derivada\n da função quadrática usando h de base decimal",
    x_label="h",
    y_label="Erro Absoluto",
    plot_filename="erroh10.png")
# Out:
# h=1 	 absolute_error=1.0
# h=0.1 	 absolute_error=0.10000000000000187
# h=0.01 	 absolute_error=0.010000000000000675
# h=0.001 	 absolute_error=0.0009999999996974651
# h=0.0001 	 absolute_error=9.999999917198465e-05
# h=1e-05 	 absolute_error=1.0000013929811757e-05
# h=1e-06 	 absolute_error=9.999243673064484e-07
# h=1e-07 	 absolute_error=1.0108780656992167e-07
# h=1e-08 	 absolute_error=1.21549419418443e-08
# h=1e-09 	 absolute_error=1.6548074199818075e-07
# h=1e-10 	 absolute_error=1.6548074199818075e-07
# h=1e-11 	 absolute_error=1.6548074199818075e-07
# h=1e-12 	 absolute_error=0.00017780116468202323
# h=1e-13 	 absolute_error=0.0015985556747182272
# h=1e-14 	 absolute_error=0.0015985556747182272
# h=1e-15 	 absolute_error=0.22044604925031308
# h=1e-16 	 absolute_error=2.0
# h=1e-17 	 absolute_error=2.0
# h=1e-18 	 absolute_error=2.0
# h=1e-19 	 absolute_error=2.0
# h=1e-20 	 absolute_error=2.0

# %% [markdown]
# Veja-se que os valores do erro absoluto calculados para $h=10^{-16}$, $h=10^{-16}$, $h=10^{-16}$, $h=10^{-16}$ e $h=10^{-16}$ são todos $2.0$. Se recorrermos ao desenvolvimento algébrico da expressão $$\Delta (h) = \left|f'(x)-\frac{f(x+h)-f(x)}{h}\right|   $$ para estes valores de $h$ obtemos \begin{equation}
# \begin{split}
#     \Delta (10^{-16}) &= 2 + 10^{-16} - 2 \\
#     \Delta (10^{-17}) &= 2 + 10^{-17} - 2 \\
#     \Delta (10^{-18}) &= 2 + 10^{-18} - 2 \\
#     \Delta (10^{-19}) &= 2 + 10^{-19} - 2 \\
#     \Delta (10^{-20}) &= 2 + 10^{-20} - 2 \\
# \end{split}
# \end{equation}
# que resulta em
# \begin{equation}
# \begin{split}
#     \Delta (10^{-16}) &= 10^{-16} \\
#     \Delta (10^{-17}) &= 10^{-17} \\
#     \Delta (10^{-18}) &= 10^{-18} \\
#     \Delta (10^{-19}) &= 10^{-19} \\
#     \Delta (10^{-20}) &= 10^{-20} \\
# \end{split}
# \end{equation}
# No entanto, sendo que a precisão do computador é de ordem superior a estes valores (provavelmente entre $10^{-15}$ e $10^{-16}$, o computador não consegue distinguir os dois valores pelo que devolve zero para $$f'(x) = \frac{f(x+h)-f(x)}{h} $$ nos valores de $h$ referidos e, consequentemente, $\Delta (h) = 2$ para esses mesmos valores.

# %%
2+10**(-15)-2
# Out:
# 8.881784197001252e-16

# %%
2+10**(-16)-2
# Out:
# 0.0

# %%
2+10**(-17)-2
# Out:
# 0.0

# %%
2+10**(-18)-2
# Out:
# 0.0

# %%
2+10**(-19)-2
# Out:
# 0.0

# %%
2+10**(-20)-2
# Out:
# 0.0

# %% [markdown]
# Veja-se nas linhas 43 e 44 como a máquina consegue computar corretamente 10^(-18) mas não  2+10^(-18)

# %%
10**(-18)
# Out:
# 1e-18

# %%
2+10**(-18)
# Out:
# 2.0

# %% [markdown]
# Outros comentários podem ser feitos sobre a igualdade de erros para $h=10^{-9}$, $h=10^{-10}$ e $h=10^{-11}$; $h=10^{-13}$ e $h=10^{-14}$, que se deve aos arredondamentos feitos pela máquina, devido ao caráter discreto dos floating points.

# %% [markdown]
# "On a typical machine running Python, there are 53 bits of precision available for a Python float" - https://docs.python.org/2/tutorial/floatingpoint.html

# %%
from decimal import *

Decimal(2+10**(-18))
# Out:
# Decimal('2')

# %% [markdown]
# A função decimal.Decimal permite-nos ver como o valor que inserimos é realmente guardado no float do Python.

# %% [markdown]
# Repetindo o mesmo processo agora para valores de h de base binária.

# %%
valores_h2 = [2**(-i) for i in range(61)]
erros_base2 = DerivativeApproxManager(x_point=1,
                                       function=f,
                                       function_derivative=f_linha,
                                       h_values=valores_h2)
erros_base2.absolute_error_per_h(
    plot_title="Erros Absolutos de Aproximações à primeira derivada\n da função quadrática usando h de base binária",
    x_label="h",
    y_label="Erro Absoluto",
    plot_filename="erroh2.png")
# Out:
# h=1 	 absolute_error=1.0
# h=0.5 	 absolute_error=0.5
# h=0.25 	 absolute_error=0.25
# h=0.125 	 absolute_error=0.125
# h=0.0625 	 absolute_error=0.0625
# h=0.03125 	 absolute_error=0.03125
# h=0.015625 	 absolute_error=0.015625
# h=0.0078125 	 absolute_error=0.0078125
# h=0.00390625 	 absolute_error=0.00390625
# h=0.001953125 	 absolute_error=0.001953125
# h=0.0009765625 	 absolute_error=0.0009765625
# h=0.00048828125 	 absolute_error=0.00048828125
# h=0.000244140625 	 absolute_error=0.000244140625
# h=0.0001220703125 	 absolute_error=0.0001220703125
# h=6.103515625e-05 	 absolute_error=6.103515625e-05
# h=3.0517578125e-05 	 absolute_error=3.0517578125e-05
# h=1.52587890625e-05 	 absolute_error=1.52587890625e-05
# h=7.62939453125e-06 	 absolute_error=7.62939453125e-06
# h=3.814697265625e-06 	 absolute_error=3.814697265625e-06
# h=1.9073486328125e-06 	 absolute_error=1.9073486328125e-06
# h=9.5367431640625e-07 	 absolute_error=9.5367431640625e-07
# h=4.76837158203125e-07 	 absolute_error=4.76837158203125e-07
# h=2.384185791015625e-07 	 absolute_error=2.384185791015625e-07
# h=1.1920928955078125e-07 	 absolute_error=1.1920928955078125e-07
# h=5.960464477539063e-08 	 absolute_error=5.960464477539063e-08
# h=2.9802322387695312e-08 	 absolute_error=2.9802322387695312e-08
# h=1.4901161193847656e-08 	 absolute_error=1.4901161193847656e-08
# h=7.450580596923828e-09 	 absolute_error=0.0
# h=3.725290298461914e-09 	 absolute_error=0.0
# h=1.862645149230957e-09 	 absolute_error=0.0
# h=9.313225746154785e-10 	 absolute_error=0.0
# h=4.656612873077393e-10 	 absolute_error=0.0
# h=2.3283064365386963e-10 	 absolute_error=0.0
# h=1.1641532182693481e-10 	 absolute_error=0.0
# h=5.820766091346741e-11 	 absolute_error=0.0
# h=2.9103830456733704e-11 	 absolute_error=0.0
# h=1.4551915228366852e-11 	 absolute_error=0.0
# h=7.275957614183426e-12 	 absolute_error=0.0
# h=3.637978807091713e-12 	 absolute_error=0.0
# h=1.8189894035458565e-12 	 absolute_error=0.0
# h=9.094947017729282e-13 	 absolute_error=0.0
# h=4.547473508864641e-13 	 absolute_error=0.0
# h=2.2737367544323206e-13 	 absolute_error=0.0
# h=1.1368683772161603e-13 	 absolute_error=0.0
# h=5.684341886080802e-14 	 absolute_error=0.0
# h=2.842170943040401e-14 	 absolute_error=0.0
# h=1.4210854715202004e-14 	 absolute_error=0.0
# h=7.105427357601002e-15 	 absolute_error=0.0
# h=3.552713678800501e-15 	 absolute_error=0.0
# h=1.7763568394002505e-15 	 absolute_error=0.0
# h=8.881784197001252e-16 	 absolute_error=0.0
# h=4.440892098500626e-16 	 absolute_error=0.0
# h=2.220446049250313e-16 	 absolute_error=0.0
# h=1.1102230246251565e-16 	 absolute_error=2.0
# h=5.551115123125783e-17 	 absolute_error=2.0
# h=2.7755575615628914e-17 	 absolute_error=2.0
# h=1.3877787807814457e-17 	 absolute_error=2.0
# h=6.938893903907228e-18 	 absolute_error=2.0
# h=3.469446951953614e-18 	 absolute_error=2.0
# h=1.734723475976807e-18 	 absolute_error=2.0
# h=8.673617379884035e-19 	 absolute_error=2.0
